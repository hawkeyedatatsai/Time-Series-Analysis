# %% [markdown]
# # What is Pandas DataReader?
# Pandas DataReader is a Python package that allows us to access data sources from the internet and automatically create dataframes with the information. It is commonly used with financial data. Some common sources include:
#
# - Yahoo Finance
# - Google Finance
# - World Bank

# %% [markdown]
# ## Yahoo Finance
#
# Each source uses a slightly different format. The lesson below with demonstrate how to access data from Yahoo Finance. We will first define a start and end date. We will use Jan 1, 2001, as our start date and today's date as our end date. Note that the end date will vary depending on today's date.

# %%
import datetime as dt
##  saving today as string for pandas DataReader
today = dt.datetime.now().strftime("%Y-%m-%d")
today
# Out:
# '2023-09-25'

# %%
start_date = '2001-01-01'
end_date = today

# %%
##  Pandas DataReader Import
import pandas_datareader as pdr
##  Get MSFT stock price for 2012-2020 from Yahoo Finance
msft = pdr.DataReader('MSFT','yahoo',start_date, end_date)
msft
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [3], line 4
#       2 import pandas_datareader as pdr
#       3 ##  Get MSFT stock price for 2012-2020 from Yahoo Finance
# ----> 4 msft = pdr.DataReader('MSFT','yahoo',start_date, end_date)
#       5 msft
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pandas_datareader/data.py:370, in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     367     raise NotImplementedError(msg)
#     369 if data_source == "yahoo":
# --> 370     return YahooDailyReader(
#     371         symbols=name,
#     372         start=start,
#     373         end=end,
#     374         adjust_price=False,
#     375         chunksize=25,
#     376         retry_count=retry_count,
#     377         pause=pause,
#     378         session=session,
#     379     ).read()
#     381 elif data_source == "iex":
#     382     return IEXDailyReader(
#     383         symbols=name,
#     384         start=start,
#    (...)
#     390         session=session,
#     391     ).read()
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pandas_datareader/base.py:253, in _DailyBaseReader.read(self)
#     251 # If a single symbol, (e.g., 'GOOG')
#     252 if isinstance(self.symbols, (string_types, int)):
# --> 253     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#     254 # Or multiple symbols, (e.g., ['GOOG', 'AAPL', 'MSFT'])
#     255 elif isinstance(self.symbols, DataFrame):
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pandas_datareader/yahoo/daily.py:153, in YahooDailyReader._read_one_data(self, url, params)
#     151 try:
#     152     j = json.loads(re.search(ptrn, resp.text, re.DOTALL).group(1))
# --> 153     data = j["context"]["dispatcher"]["stores"]["HistoricalPriceStore"]
#     154 except KeyError:
#     155     msg = "No data fetched for symbol {} using {}"
#
# TypeError: string indices must be integers

# %% [markdown]
# ### Troubleshooting
# Pandas DataReader occasionally has issues connecting to the Yahoo finance API. This is not due to a problem with your computer/environment. The Yahoo API is one of the only free-to-use data sources included in Panda's DataReader, so we need to use a workaround to get Yahoo Finance working correctly.
#
# Install the yfinance package (you only need to do this once)
# Note: if you install the package in your notebook, you should comment out the pip install command after you have successfully installed the package.

# %%
# in a notebook, use ! before a pip command 
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /Users/heng-tsertsai/anaconda3/envs/dojo-env/lib/python3.9/site-packages (0.2.30)
# Requirement already satisfied: numpy>=1.16.5 in /Users/heng-tsertsai/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from yfinance) (1.23.4)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/heng-tsertsai/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: requests>=2.31 in /Users/heng-tsertsai/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/heng-tsertsai/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from yfinance) (2.3.8)
# Requirement already satisfied: peewee>=3.16.2 in /Users/heng-tsertsai/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from yfinance) (3.16.3)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/heng-tsertsai/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: pandas>=1.3.0 in /Users/heng-tsertsai/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from yfinance) (1.5.2)
# Requirement already satisfied: appdirs>=1.4.4 in /Users/heng-tsertsai/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: html5lib>=1.1 in /Users/heng-tsertsai/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from yfinance) (1.1)
# Requirement already satisfied: pytz>=2022.5 in /Users/heng-tsertsai/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: lxml>=4.9.1 in /Users/heng-tsertsai/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/heng-tsertsai/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.2.post1)
# Requirement already satisfied: webencodings in /Users/heng-tsertsai/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in /Users/heng-tsertsai/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/heng-tsertsai/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/heng-tsertsai/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/heng-tsertsai/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from requests>=2.31->yfinance) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /Users/heng-tsertsai/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/heng-tsertsai/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from requests>=2.31->yfinance) (1.26.13)

# %%
#Import the package and run the pdr_override function
import yfinance as yfin
yfin.pdr_override()

#Then, change your import statement for pandas_datareader ( add ".data" to the import)
import pandas_datareader.data as pdr

#Finally, use the pdr.get_data_yahoo function instead of the pdr.DataReader function. 
#Note that we no longer need to include "yahoo" as an argument since this function 
#is already specifically for Yahoo.

msft = pdr.get_data_yahoo('MSFT',start_date, end_date)
msft
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2001-01-02   22.062500   22.500000   21.437500   21.687500   13.472753
# 2001-01-03   21.593750   24.437500   21.562500   23.968750   14.889915
# 2001-01-04   23.906250   25.250000   23.437500   24.218750   15.045222
# 2001-01-05   24.250000   24.937500   23.781250   24.562500   15.258764
# 2001-01-08   24.468750   24.875000   23.343750   24.468750   15.200530
# ...                ...         ...         ...         ...         ...
# 2023-09-18  327.799988  330.399994  326.359985  329.059998  329.059998
# 2023-09-19  326.170013  329.390015  324.510010  328.649994  328.649994
# 2023-09-20  329.510010  329.589996  320.510010  320.769989  320.769989
# 2023-09-21  319.260010  325.350006  315.000000  319.529999  319.529999
# 2023-09-22  321.320007  321.450012  316.149994  317.010010  317.010010
#
#                Volume
# Date
# 2001-01-02   82413200
# 2001-01-03  135962200
# 2001-01-04  112397000
# 2001-01-05   93414600
# 2001-01-08   79817600
# ...               ...
# 2023-09-18   16834200
# 2023-09-19   16505900
# 2023-09-20   21436500
# 2023-09-21   35529500
# 2023-09-22   21429700
#
# [5717 rows x 6 columns]

# %%
# !pip install yfinance
#import yfinance as yfin
#yfin.pdr_override()
##  Pandas DataReader Import
#import pandas_datareader.data as pdr
# example use with new function
#msft = pdr.get_data_yahoo('MSFT',start_date, end_date)

# %%
# try google stok now
##  Get GOOGL price for 2012-2020 from Yahoo Finance
googl = pdr.get_data_yahoo('GOOGL',start_date, end_date)
googl
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2004-08-19    2.502503    2.604104    2.401401    2.511011    2.511011
# 2004-08-20    2.527778    2.729730    2.515015    2.710460    2.710460
# 2004-08-23    2.771522    2.839840    2.728979    2.737738    2.737738
# 2004-08-24    2.783784    2.792793    2.591842    2.624374    2.624374
# 2004-08-25    2.626627    2.702703    2.599600    2.652653    2.652653
# ...                ...         ...         ...         ...         ...
# 2023-09-18  136.610001  139.160004  136.610001  138.210007  138.210007
# 2023-09-19  137.419998  138.410004  136.619995  138.039993  138.039993
# 2023-09-20  138.080002  138.080002  133.619995  133.740005  133.740005
# 2023-09-21  131.440002  132.229996  130.070007  130.440002  130.440002
# 2023-09-22  130.759995  132.029999  129.600006  130.250000  130.250000
#
#                Volume
# Date
# 2004-08-19  893181924
# 2004-08-20  456686856
# 2004-08-23  365122512
# 2004-08-24  304946748
# 2004-08-25  183772044
# ...               ...
# 2023-09-18   21861300
# 2023-09-19   20353700
# 2023-09-20   29927500
# 2023-09-21   31488700
# 2023-09-22   26385200
#
# [4807 rows x 6 columns]

# %%
#Finally, we will obtain data on Apple stocks (AAPL):
##  Get AAPL stock price for 2012-2020 from Yahoo Finance
apple = pdr.get_data_yahoo('AAPL',start_date, end_date)
apple
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2001-01-02    0.265625    0.272321    0.260045    0.265625    0.225462
# 2001-01-03    0.258929    0.297991    0.257813    0.292411    0.248197
# 2001-01-04    0.323940    0.330357    0.300223    0.304688    0.258618
# 2001-01-05    0.302455    0.310268    0.286830    0.292411    0.248197
# 2001-01-08    0.302455    0.303292    0.284598    0.295759    0.251039
# ...                ...         ...         ...         ...         ...
# 2023-09-18  176.479996  179.380005  176.169998  177.970001  177.970001
# 2023-09-19  177.520004  179.630005  177.130005  179.070007  179.070007
# 2023-09-20  179.259995  179.699997  175.399994  175.490005  175.490005
# 2023-09-21  174.550003  176.300003  173.860001  173.929993  173.929993
# 2023-09-22  174.669998  177.080002  174.050003  174.789993  174.789993
#
#                Volume
# Date
# 2001-01-02  452312000
# 2001-01-03  817073600
# 2001-01-04  739396000
# 2001-01-05  412356000
# 2001-01-08  373699200
# ...               ...
# 2023-09-18   67257600
# 2023-09-19   51826900
# 2023-09-20   58436200
# 2023-09-21   63047900
# 2023-09-22   56663000
#
# [5717 rows x 6 columns]

# %%
#make a DataFrame with the Adjusted Close for Google, Microsoft, and Apple.
import pandas as pd
stocks_df = pd.DataFrame({"AAPL": apple['Adj Close'],
             "MSFT": msft['Adj Close'],
             'GOOGL': googl['Adj Close']})
stocks_df
# Out:
#                   AAPL        MSFT       GOOGL
# Date
# 2001-01-02    0.225462   13.472753         NaN
# 2001-01-03    0.248197   14.889915         NaN
# 2001-01-04    0.258618   15.045222         NaN
# 2001-01-05    0.248197   15.258764         NaN
# 2001-01-08    0.251039   15.200530         NaN
# ...                ...         ...         ...
# 2023-09-18  177.970001  329.059998  138.210007
# 2023-09-19  179.070007  328.649994  138.039993
# 2023-09-20  175.490005  320.769989  133.740005
# 2023-09-21  173.929993  319.529999  130.440002
# 2023-09-22  174.789993  317.010010  130.250000
#
# [5717 rows x 3 columns]

# %%
stocks_df.plot();

# %% [markdown]
# ## Downloading Crypto Currencies

# %%
bitcoin= pdr.get_data_yahoo('BTC-USD',start_date,end_date);
etherium =  pdr.get_data_yahoo('ETH-USD',start_date,end_date);
crypto_df = pd.DataFrame({'BTC':bitcoin['Adj Close'],
                         'Eth':etherium['Adj Close']})
crypto_df
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#                      BTC          Eth
# Date
# 2014-09-17    457.334015          NaN
# 2014-09-18    424.440002          NaN
# 2014-09-19    394.795990          NaN
# 2014-09-20    408.903992          NaN
# 2014-09-21    398.821014          NaN
# ...                  ...          ...
# 2023-09-20  27132.007812  1622.890625
# 2023-09-21  26567.632812  1584.307007
# 2023-09-22  26579.568359  1593.268311
# 2023-09-23  26579.390625  1593.857788
# 2023-09-24  26256.826172  1580.853394
#
# [3295 rows x 2 columns]

# %%
crypto_df.plot();

# %% [markdown]
# # Summary
# This lesson introduced you to Pandas DataReader. Specifically, we extracted stock data from Yahoo Finance.
